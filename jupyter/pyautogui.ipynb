# %%
import pyautogui as py

# %%
x,y=py.size()

# %%
import time

# %%
time.sleep(5)
py.moveTo(x-500,y-500)

# %%
time.sleep(5)
py.dragTo(x-500,y-500,duration=0.1)

# %%
# Out:
#   Cell In[8], line 1
#     python3 -m venv venv
#                ^
# SyntaxError: invalid syntax

# %%
py.displayMousePosition()
# Out:
# Press Ctrl-C to quit.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 py.displayMousePosition()
#
# File ~/.local/lib/python3.10/site-packages/pyautogui/__init__.py:1759, in displayMousePosition(xOffset, yOffset)
#    1757     pixelColor = ("NaN", "NaN", "NaN")
#    1758 else:
# -> 1759     pixelColor = pyscreeze.screenshot().getpixel(
#    1760         (x, y)
#    1761     )  # NOTE: On Windows & Linux, getpixel() returns a 3-integer tuple, but on macOS it returns a 4-integer tuple.
#    1762 positionStr += " RGB: (" + str(pixelColor[0]).rjust(3)
#    1763 positionStr += ", " + str(pixelColor[1]).rjust(3)
#
# File ~/.local/lib/python3.10/site-packages/pyscreeze/__init__.py:628, in _screenshot_linux(imageFilename, region)
#     624     raise PyScreezeException(
# ...
